# %% [markdown]
# # **AI Storytelling**
#
# <img src="assets/logo.jpg" width="500" height="300">
#
# This is Natural Language Processing platform that targets on conversion of short stories to audiobooks with features:
# - characters extraction from text,
# - voice generation by dialogues, narration and characters,
# - musical background creation by text,
# - activities sound generation by lines, and
# - combination of all above features to create the audiobook.
#
# Based on the success of the project, it could be extended with image or video processing features in upcoming days.

# %% [markdown]
# ### Import Libraries and Functions

# %%
# basic libraries
import os
import pandas as pd

# %%
# ignore warnings
import warnings
warnings.filterwarnings('ignore')

# %%
# nlp libraries
import spacy
nlp = spacy.load("en_core_web_lg")

# %%
# text-to-speech libraries
from gtts import gTTS
from moviepy.editor import concatenate_audioclips, AudioFileClip
import librosa
import soundfile as sf

# %% [markdown]
# ### Files and Dataframes Defining

# %%
# checking stories
os.listdir("stories")
# Out:
# ['beautiful garden.txt', 'cafe at midnight.txt', 'the painted door.txt']

# %%
# input title
title = input("Enter text file name:")
# Out:
# Enter text file name: cafe at midnight

# %%
# opening text file
story = f"stories/{title}.txt"
with open(story, "r") as f:
    text = f.read()

# %%
# create dataframes
df_characters = pd.DataFrame(columns=["cid", "name", "frequency", "features"])
df_lines = pd.DataFrame(columns=["pid", "ndid", "character", "dialogue", "narration"])

# %% [markdown]
# # Characters Identification

# %%
# finding personal entities from text
entities = nlp(text).ents
personal_entities = []
for entity in entities:
    if entity.label_ == 'PERSON':
        personal_entities.append(entity.text)
personal_entities = list(set(personal_entities))

# %%
# adding persons and counts to df_characters
cid_num = 0
for person in personal_entities:
    df_characters = df_characters._append({
        'cid': cid_num, 'name': person, 'frequency': text.count(person), 'features': None}, ignore_index=True)
    cid_num += 1

# %%
# characters
df_characters.head(10)
# Out:
#   cid  name frequency features
# 0   0  Alex         7     None

# %% [markdown]
# # Lines Identification

# %%
# converting text to paragraphs
paragraphs = text.split("\n")
non_empty_paragraphs = list(filter(lambda x: x != '', paragraphs))

# %%
# function to identify narrations and dialogues
def identify_narrations_and_dialogues(paragraph):
    """
    :param paragraph: string of paragraph in a story
    :return: list of tuples in (id, name_of_speaker, dialogue, narration) format
    """
    divisions = paragraph.split('"')
    divisions = list(filter(lambda x: x != '', divisions))
    i = 0
    narrations_and_dialogues = []
    for division in divisions:
        start_index = paragraph.find(division)
        end_index = start_index + len(division) - 1
        if '"' in paragraph[:start_index] and '"' in paragraph[end_index:]:
            narrations_and_dialogues.append((i, None, division, None))
            print(division, "D")
        else:
            narrations_and_dialogues.append((i, None, None, division))
        i += 1
    return narrations_and_dialogues

# %%
# identifying lines (narrations or dialogues) from each paragraphs
pid_num = 0
for paragraph in non_empty_paragraphs:
    for row in [(pid_num,)+nad for nad in identify_narrations_and_dialogues(paragraph)]:
        print(row)
        df_lines = df_lines._append(pd.Series(row, index=df_lines.columns), ignore_index=True)
    pid_num += 1
# Out:
# (0, 0, None, None, 'Midnight in the heart of the city, the neon signs reflected off the wet pavement as a lone caf̩ stood open. Inside, Alex sat by the window, sipping coffee and lost in thought.')
# (1, 0, None, None, 'The door creaked open, and a mysterious figure entered, their face hidden by the shadows. They took a seat across from Alex without uttering a word.')
# Late night for a coffee, isn't it? D
# (2, 0, None, None, 'Alex raised an eyebrow. ')
# (2, 1, None, "Late night for a coffee, isn't it?", None)
# Some stories unfold when the world sleeps. D
# (3, 0, None, None, 'The stranger chuckled, a voice tinged with intrigue. ')
# (3, 1, None, 'Some stories unfold when the world sleeps.', None)
# What kind of stories? D
# (4, 0, None, None, 'Intrigued, Alex leaned forward. ')
# (4, 1, None, 'What kind of stories?', None)
# Stories of the forgotten, the ones that only emerge when the city is draped in silence, D
# (5, 0, None, 'Stories of the forgotten, the ones that only emerge when the city is draped in silence,', None)
# (5, 1, None, None, ' the stranger replied mysteriously.')
# (6, 0, None, None, 'As the two continued to talk, a bond formed between them, woven through tales of lost dreams and midnight revelations. The caf̩ became a realm where time seemed to stand still, and the ordinary world faded away.')
# You know, D
#  Alex said,  D
# this feels like a chapter from a novel. A meeting in the dead of night, sharing stories with a stranger. D
# (7, 0, None, 'You know,', None)
# (7, 1, None, ' Alex said, ', None)
# (7, 2, None, 'this feels like a chapter from a novel. A meeting in the dead of night, sharing stories with a stranger.', None)
# Perhaps it is. Life has a way of scripting its own narratives. D
# (8, 0, None, None, 'The stranger smirked. ')
# (8, 1, None, 'Perhaps it is. Life has a way of scripting its own narratives.', None)
# Until our paths cross again, Alex. D
# (9, 0, None, None, 'As the clock struck 3 AM, the stranger stood to leave, their features still concealed by shadows. ')
# (9, 1, None, 'Until our paths cross again, Alex.', None)
# (10, 0, None, None, 'And with that, they vanished into the night, leaving Alex alone in the dimly lit caf̩. The city outside seemed to wake up, but the encounter lingered like a chapter from a book, waiting to be explored in the pages of the next unexpected adventure.')

# %%
# lines
df_lines.head(10)
# Out:
#   pid ndid character                                    dialogue  \
# 0   0    0      None                                        None
# 1   1    0      None                                        None
# 2   2    0      None                                        None
# 3   2    1      None          Late night for a coffee, isn't it?
# 4   3    0      None                                        None
# 5   3    1      None  Some stories unfold when the world sleeps.
# 6   4    0      None                                        None
# 7   4    1      None                       What kind of stories?
# 8   5    0      None                                        None
# 9   5    1      None          the stranger replied mysteriously.
#
#                                            narration
# 0  Midnight in the heart of the city, the neon si...
# 1  The door creaked open, and a mysterious figure...
# 2                           Alex raised an eyebrow.
# 3                                               None
# 4  The stranger chuckled, a voice tinged with int...
# 5                                               None
# 6                   Intrigued, Alex leaned forward.
# 7                                               None
# 8  Stories of the forgotten, the ones that only e...
# 9                                               None

# %% [markdown]
# # Audio Generation

# %%
# creating audios
print("Step 1: CONVERSIONS")
for index, row in df_lines.iterrows():
    if row['dialogue'] is not None:
        speech_gtts = gTTS(text=row['dialogue'], lang='en', slow=False, tld='co.in')
    else:
        speech_gtts = gTTS(text=row['narration'], lang='en', slow=False, tld='ie')
    temp_file = f"conversions/{index}.mp3"
    print(f"Line {index+1}/{df_lines.shape[0]} converted.")
    speech_gtts.save(temp_file)
print("Conversions finished.")
# Out:
# Step 1: CONVERSIONS
# Line 1/418 converted.
# Line 2/418 converted.
# Line 3/418 converted.
# Line 4/418 converted.
# Line 5/418 converted.
# Line 6/418 converted.
# Line 7/418 converted.
# Line 8/418 converted.
# Line 9/418 converted.
# Line 10/418 converted.
# Line 11/418 converted.
# Line 12/418 converted.
# Line 13/418 converted.
# Line 14/418 converted.
# Line 15/418 converted.
# Line 16/418 converted.
# Line 17/418 converted.
# Line 18/418 converted.
# Line 19/418 converted.
# Line 20/418 converted.
# Line 21/418 converted.
# Line 22/418 converted.
# Line 23/418 converted.
# Line 24/418 converted.
# Line 25/418 converted.
# Line 26/418 converted.
# Line 27/418 converted.
# Line 28/418 converted.
# Line 29/418 converted.
# Line 30/418 converted.
# Line 31/418 converted.
# Line 32/418 converted.
# Line 33/418 converted.
# Line 34/418 converted.
# Line 35/418 converted.
# Line 36/418 converted.
# Line 37/418 converted.
# Line 38/418 converted.
# Line 39/418 converted.
# Line 40/418 converted.
# Line 41/418 converted.
# Line 42/418 converted.
# Line 43/418 converted.
# Line 44/418 converted.
# Line 45/418 converted.
# Line 46/418 converted.
# Line 47/418 converted.
# Line 48/418 converted.
# Line 49/418 converted.
# Line 50/418 converted.
# Line 51/418 converted.
# Line 52/418 converted.
# Line 53/418 converted.
# Line 54/418 converted.
# Line 55/418 converted.
# Line 56/418 converted.
# Line 57/418 converted.
# Line 58/418 converted.
# Line 59/418 converted.
# Line 60/418 converted.
# Line 61/418 converted.
# Line 62/418 converted.
# Line 63/418 converted.
# Line 64/418 converted.
# Line 65/418 converted.
# Line 66/418 converted.
# Line 67/418 converted.
# Line 68/418 converted.
# Line 69/418 converted.
# Line 70/418 converted.
# Line 71/418 converted.
# Line 72/418 converted.
# Line 73/418 converted.
# Line 74/418 converted.
# Line 75/418 converted.
# Line 76/418 converted.
# Line 77/418 converted.
# Line 78/418 converted.
# Line 79/418 converted.
# Line 80/418 converted.
# Line 81/418 converted.
# Line 82/418 converted.
# Line 83/418 converted.
# Line 84/418 converted.
# Line 85/418 converted.
# Line 86/418 converted.
# Line 87/418 converted.
# Line 88/418 converted.
# Line 89/418 converted.
# Line 90/418 converted.
# Line 91/418 converted.
# Line 92/418 converted.
# Line 93/418 converted.
# Line 94/418 converted.
# Line 95/418 converted.
# Line 96/418 converted.
# Line 97/418 converted.
# Line 98/418 converted.
# Line 99/418 converted.
# Line 100/418 converted.
# Line 101/418 converted.
# Line 102/418 converted.
# Line 103/418 converted.
# Line 104/418 converted.
# Line 105/418 converted.
# Line 106/418 converted.
# Line 107/418 converted.
# Line 108/418 converted.
# Line 109/418 converted.
# Line 110/418 converted.
# Line 111/418 converted.
# Line 112/418 converted.
# Line 113/418 converted.
# Line 114/418 converted.
# Line 115/418 converted.
# Line 116/418 converted.
# Line 117/418 converted.
# Line 118/418 converted.
# Line 119/418 converted.
# Line 120/418 converted.
# Line 121/418 converted.
# Line 122/418 converted.
# Line 123/418 converted.
# Line 124/418 converted.
# Line 125/418 converted.
# Line 126/418 converted.
# Line 127/418 converted.
# Line 128/418 converted.
# Line 129/418 converted.
# Line 130/418 converted.
# Line 131/418 converted.
# Line 132/418 converted.
# Line 133/418 converted.
# Line 134/418 converted.
# Line 135/418 converted.
# Line 136/418 converted.
# Line 137/418 converted.
# Line 138/418 converted.
# Line 139/418 converted.
# Line 140/418 converted.
# Line 141/418 converted.
# Line 142/418 converted.
# Line 143/418 converted.
# Line 144/418 converted.
# Line 145/418 converted.
# Line 146/418 converted.
# Line 147/418 converted.
# Line 148/418 converted.
# Line 149/418 converted.
# Line 150/418 converted.
# Line 151/418 converted.
# Line 152/418 converted.
# Line 153/418 converted.
# Line 154/418 converted.
# Line 155/418 converted.
# Line 156/418 converted.
# Line 157/418 converted.
# Line 158/418 converted.
# Line 159/418 converted.
# Line 160/418 converted.
# Line 161/418 converted.
# Line 162/418 converted.
# Line 163/418 converted.
# Line 164/418 converted.
# Line 165/418 converted.
# Line 166/418 converted.
# Line 167/418 converted.
# Line 168/418 converted.
# Line 169/418 converted.
# Line 170/418 converted.
# Line 171/418 converted.
# Line 172/418 converted.
# Line 173/418 converted.
# Line 174/418 converted.
# Line 175/418 converted.
# Line 176/418 converted.
# Line 177/418 converted.
# Line 178/418 converted.
# Line 179/418 converted.
# Line 180/418 converted.
# Line 181/418 converted.
# Line 182/418 converted.
# Line 183/418 converted.
# Line 184/418 converted.
# Line 185/418 converted.
# Line 186/418 converted.
# Line 187/418 converted.
# Line 188/418 converted.
# Line 189/418 converted.
# Line 190/418 converted.
# Line 191/418 converted.
# Line 192/418 converted.
# Line 193/418 converted.
# Line 194/418 converted.
# Line 195/418 converted.
# Line 196/418 converted.
# Line 197/418 converted.
# Line 198/418 converted.
# Line 199/418 converted.
# Line 200/418 converted.
# Line 201/418 converted.
# Line 202/418 converted.
# Line 203/418 converted.
# Line 204/418 converted.
# Line 205/418 converted.
# Line 206/418 converted.
# Line 207/418 converted.
# Line 208/418 converted.
# Line 209/418 converted.
# Line 210/418 converted.
# Line 211/418 converted.
# Line 212/418 converted.
# Line 213/418 converted.
# Line 214/418 converted.
# Line 215/418 converted.
# Line 216/418 converted.
# Line 217/418 converted.
# Line 218/418 converted.
# Line 219/418 converted.
# Line 220/418 converted.

# %%
# combining audios
print("Step 2: COMBINATION")
clips = [AudioFileClip(f"conversions/{i}.mp3") for i in range(df_lines.shape[0])]
final_clip = concatenate_audioclips(clips)
print("Combination finished.")

# %%
# adjust speed
print("Step 3: ADJUSTMENT")
final_clip.write_audiofile("conversions/final_slow.mp3")
print("final_slow.mp3 downloaded.")
y, sr = librosa.load("conversions/final_slow.mp3", sr=None)
y_speed = librosa.effects.time_stretch(y, rate=1.25)
print("Speeded over.")

# %%
# removing audios
print("Step 4: REMOVAL")
for i in range(df_lines.shape[0]):
    os.remove(f"conversions/{i}.mp3")
    print(f"Removed {i}.mp3")
os.remove("conversions/final_slow.mp3")
print("Removal over.")

# %%
# downloading final audio
print("Step 5: DOWNLOADING")
final_title = title.replace(" ", "_")
sf.write(f"audiobooks/{final_title}.mp3", y_speed, sr)
print(f"{final_title}.mp3 downloaded")
